# %% [markdown]
# ## 안테나
# - 모든 경우를 다고려하면 시간초과 -> 40억
# - 솔루션
#     - 1. 오름차순
#     - 2. 중간인덱스
#     - 3. 중간인덱스는 짝수-> 2개중하나, 홀수->가운데
#     - (n-1)//2하면 짝 홀 만족

# %%
n = int(input())
a = list(map(int, input().split()))
a.sort()
print(a[(n-1)//2])
# Out:
# 4
# 1 5 7 9
# 5
